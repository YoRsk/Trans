# %%
# !pip install git+
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import rasterio
#       2 import numpy as np
#       3 import matplotlib as plt
#
# ModuleNotFoundError: No module named 'rasterio'

# %%
# !pip install numpy
# !pip install opencv-python
# !pip install rasterio
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\hasee\anaconda3\lib\site-packages (1.21.5)
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\hasee\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# Collecting rasterio
#   Downloading rasterio-1.3.6-cp39-cp39-win_amd64.whl (22.3 MB)
#      ---------------------------------------- 22.3/22.3 MB 3.0 MB/s eta 0:00:00
# Collecting snuggs>=1.4.1
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: attrs in c:\users\hasee\anaconda3\lib\site-packages (from rasterio) (21.4.0)
# Collecting cligj>=0.5
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy>=1.18 in c:\users\hasee\anaconda3\lib\site-packages (from rasterio) (1.21.5)
# Requirement already satisfied: click>=4.0 in c:\users\hasee\anaconda3\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: setuptools in c:\users\hasee\anaconda3\lib\site-packages (from rasterio) (61.2.0)
# Collecting click-plugins
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: certifi in c:\users\hasee\anaconda3\lib\site-packages (from rasterio) (2022.12.7)
# Collecting affine
#   Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: colorama in c:\users\hasee\anaconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.4)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\hasee\anaconda3\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.4)
# Installing collected packages: snuggs, affine, cligj, click-plugins, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.3.6 snuggs-1.4.7
# Requirement already satisfied: matplotlib in c:\users\hasee\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hasee\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\hasee\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import rasterio
import numpy as np
from matplotlib import pyplot as plt

# Replace 'multispectral_image.tif' with the path to your image file.
image_file = 'data/20210903_jinjiayama_multi_75m_Terra.tif'

with rasterio.open(image_file) as src:
    multi_spectral_data = src.read()
    profile = src.profile
    transform = src.transform

# %%
from rasterio.plot import show
show(multi_spectral_data[0, :, :])
# Out:
# <Axes: >
